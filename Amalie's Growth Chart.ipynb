# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

url = 'https://www.cdc.gov/growthcharts/html_charts/wtageinf.htm#females'
df = pd.read_html(url, header = 0)
df2 = df[1].reset_index(drop=True)
my_df = df2.drop(['Age (in months)', '3rd Percentile Weight (in kilograms)','97th Percentile Weight (in kilograms)'], axis=1)
amay = [3.2, 3.8, 4.3, 5, 5.8, 6.5, 7,7.8,8.4, 8.8, 9.2, 9.6, 10,10.4, 10.8, 11.2, 11.5,11.8, 12.1, 12.3, 12.6, 
        12.9, 13.2, 13.5, 13.8, 14, 14.3, 14.6,15, 15.2,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
amax = [0, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 
        18.5,19.5, 20.5, 21.5, 22.5, 23.5, 24.5,25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5, 33.5, 34.5, 35.5, 36]

urll = 'https://www.cdc.gov/growthcharts/html_charts/lenageinf.htm#females'
dfl = pd.read_html(urll, header = 0)
dfl2 = dfl[1].reset_index(drop=True)
my_dfl = dfl2.drop(['Age (in months)', '3rd Percentile Length (in centimeters)','97th Percentile Length (in centimeters)'], axis=1)
amaly = [49, 51,55,58,60,62,64,66,67,69,70,71,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
amalx = [0, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5,19.5, 20.5, 21.5, 22.5, 23.5, 24.5,25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5, 33.5, 34.5, 35.5, 36]

fig, ax = plt.subplots(1,2,figsize=(7,4))
color = ['pink','pink','pink','pink','pink','pink','pink']

ax[0].scatter(amax, amay, c='deeppink', marker='*',  label="Amalie", s=5, zorder=2)
ax[0].set_xlabel("Age ( MONTHS )")
ax[0].set_ylabel("WEIGHT ( kg )")
ax[0].minorticks_on()
ax[0].grid(which = "major", color="lightgray", linewidth=0.5)
ax[0].grid(which = "minor",color = "lightgray", linestyle="--", linewidth=0.5)
my_df.plot(xlim=[0,36], ylim=[0,18],ax=ax[0], color=color, zorder=1, legend=False)

ax[1].scatter(amalx, amaly, c='deeppink', marker='*',  label="Amalie", s=5, zorder=2)
ax[1].set_xlabel("Age ( MONTHS )")
ax[1].set_ylabel("LENGTH ( cm )")
ax[1].minorticks_on()
ax[1].grid(which = "major", color="lightgray", linewidth=0.5)
ax[1].grid(which = "minor",color = "lightgray", linestyle="--", linewidth=0.5)
my_dfl.plot(xlim=[0,36], ylim=[35,110],ax=ax[1], color=color,  zorder=1, legend=False)

plt.rcParams["figure.autolayout"] = True
matplotlib.rcParams['legend.fontsize'] = 7
plt.legend(['Amalie','95th','90th','75th','50th', '25th', '10th', '5th'],bbox_to_anchor=(1.35, 0.4))
plt.tight_layout()
plt.suptitle("Amalie's Growth Chart")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
bbox_to_anchor=(1.05, 0.32)
fig, ax = plt.subplots()

line1, = ax.plot([1, 2, 3],
				label ="Line 1",
				color ="black",
				linewidth = 4,
				linestyle =':')

line2, = ax.plot([3, 2, 1],
				label ="Line 2",
				color ="green",
				linewidth = 4)


first_legend = ax.legend(handles =[line1],
						loc ='upper center')

ax.add_artist(first_legend)

ax.legend(handles =[line2], loc ='lower center')

fig.suptitle('matplotlib.axes.Axes.legend() \
function Example\n', fontweight ="bold")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

url = 'https://www.cdc.gov/growthcharts/html_charts/wtageinf.htm#females'
df = pd.read_html(url, header = 0)
df2 = df[1].reset_index(drop=True)

fig, ax = plt.subplots()

ax.plot()
# Out:
# <>:8: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:8: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/fx/6fgzgcsd4kndsf3q6rwqpvxm0000gn/T/ipykernel_8578/1051326323.py:8: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   ax.plot([1,2][1,2]);
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fx/6fgzgcsd4kndsf3q6rwqpvxm0000gn/T/ipykernel_8578/1051326323.py in <module>
#       6 fig, ax = plt.subplots()
#       7
# ----> 8 ax.plot([1,2][1,2]);
#
# TypeError: list indices must be integers or slices, not tuple
